# %%
from llm_cost_estimation import models

for model in models:
    print(f'Model Name: {model["name"]}')
    print(f'Completion Cost Per Token: {model["completion_cost_per_token"]}')
    print(f'Prompt Cost Per Token: {model["prompt_cost_per_token"]}')
    print(f'Maximum Tokens: {model["max_tokens"]}')
    print(f'Description: {model["description"]}\n')
# Out:
# Model Name: gpt-3.5-turbo-instruct
# Completion Cost Per Token: 0.002 / 1000
# Prompt Cost Per Token: 0.0015 / 1000
# Maximum Tokens: 4096
# Description: Same capabilities as the standard gpt-3.5-turbo model but uses completion rather than chat completion enpoint
#
# Model Name: gpt-3.5-turbo
# Completion Cost Per Token: 0.002 / 1000
# Prompt Cost Per Token: 0.0015 / 1000
# Maximum Tokens: 4096
# Description: Most capable GPT-3.5 model and optimized for chat at 1/10th the cost of text-davinci-003. Will be updated with our latest model iteration.
#
# Model Name: gpt-3.5-turbo-16k
# Completion Cost Per Token: 0.004 / 1000
# Prompt Cost Per Token: 0.003 / 1000
# Maximum Tokens: 16385
# Description: Same capabilities as the standard gpt-3.5-turbo model but with 4 times the context.
#
# Model Name: gpt-4-32k
# Completion Cost Per Token: 0.12 / 1000
# Prompt Cost Per Token: 0.06 / 1000
# Maximum Tokens: 32768
# Description: Same capabilities as the base gpt-4 mode but with 4x the context length. Will be updated with our latest model iteration.
#
# Model Name: gpt-4
# Completion Cost Per Token: 0.06 / 1000
# Prompt Cost Per Token: 0.03 / 1000
# Maximum Tokens: 8192
# Description: More capable than any GPT-3.5 model, able to do more complex tasks, and optimized for chat. Will be updated with our latest model iteration.
#
# Model Name: text-ada-001
# Completion Cost Per Token: 0.0004 / 1000
# Prompt Cost Per Token: 0.0004 / 1000
# Maximum Tokens: 2049
# Description: Capable of very simple tasks, usually the fastest model in the GPT-3 series, and lowest cost.
#
# Model Name: text-babbage-001
# Completion Cost Per Token: 0.0005 / 1000
# Prompt Cost Per Token: 0.0005 / 1000
# Maximum Tokens: 2049
# Description: Capable of straightforward tasks, very fast, and lower cost.
#
# Model Name: text-curie-001
# Completion Cost Per Token: 0.002 / 1000
# Prompt Cost Per Token: 0.002 / 1000
# Maximum Tokens: 2049
# Description: Very capable, faster and lower cost than Davinci.
#
# Model Name: text-davinci-001
# Completion Cost Per Token: 0.02 / 1000
# Prompt Cost Per Token: 0.02 / 1000
# Maximum Tokens: 8001
# Description: None
#
# Model Name: text-davinci-002
# Completion Cost Per Token: 0.02 / 1000
# Prompt Cost Per Token: 0.02 / 1000
# Maximum Tokens: 4097
# Description: Similar capabilities to text-davinci-003 but trained with supervised fine-tuning instead of reinforcement learning
#
# Model Name: text-davinci-003
# Completion Cost Per Token: 0.02 / 1000
# Prompt Cost Per Token: 0.02 / 1000
# Maximum Tokens: 4097
# Description: Most capable GPT-3 model. Can do any task the other models can do, often with higher quality.
#
# Model Name: gpt-4-0314
# Completion Cost Per Token: 0.06 / 1000
# Prompt Cost Per Token: 0.03 / 1000
# Maximum Tokens: 8192
# Description: Snapshot of gpt-4 from March 14th 2023. Unlike gpt-4, this model will not receive updates, and will be deprecated 3 months after a new version is released.
#
# Model Name: gpt-4-0613
# Completion Cost Per Token: 0.06 / 1000
# Prompt Cost Per Token: 0.03 / 1000
# Maximum Tokens: 8192
# Description: Snapshot of gpt-4 from June 13th 2023 with function calling data. Unlike gpt-4, this model will not receive updates, and will be deprecated 3 months after a new version is released.
#
# Model Name: gpt-4-32k-0314
# Completion Cost Per Token: 0.12 / 1000
# Prompt Cost Per Token: 0.06 / 1000
# Maximum Tokens: 32768
# Description: Snapshot of gpt-4-32 from March 14th 2023. Unlike gpt-4-32k, this model will not receive updates, and will be deprecated 3 months after a new version is released.
#
# Model Name: gpt-4-32k-0613
# Completion Cost Per Token: 0.12 / 1000
# Prompt Cost Per Token: 0.06 / 1000
# Maximum Tokens: 32768
# Description: Snapshot of gpt-4-32 from June 13th 2023. Unlike gpt-4-32k, this model will not receive updates, and will be deprecated 3 months after a new version is released.
#
# Model Name: gpt-3.5-turbo-0301
# Completion Cost Per Token: 0.002 / 1000
# Prompt Cost Per Token: 0.002 / 1000
# Maximum Tokens: 4096
# Description: Snapshot of gpt-3.5-turbo from March 1st 2023. Unlike gpt-3.5-turbo, this model will not receive updates, and will be deprecated 3 months after a new version is released.
#
# Model Name: gpt-3.5-turbo-0613
# Completion Cost Per Token: 0.002 / 1000
# Prompt Cost Per Token: 0.0015 / 1000
# Maximum Tokens: 4096
# Description: Snapshot of gpt-3.5-turbo from June 13th 2023 with function calling data. Unlike gpt-3.5-turbo, this model will not receive updates, and will be deprecated 3 months after a new version is released.
#
# Model Name: gpt-3.5-turbo-16k-0613
# Completion Cost Per Token: 0.004 / 1000
# Prompt Cost Per Token: 0.003 / 1000
# Maximum Tokens: 16385
# Description: Snapshot of gpt-3.5-turbo-16k from June 13th 2023. Unlike gpt-3.5-turbo-16k, this model will not receive updates, and will be deprecated 3 months after a new version is released.
#
# Model Name: code-davinci-002
# Completion Cost Per Token: 0.002 / 1000
# Prompt Cost Per Token: 0.002 / 1000
# Maximum Tokens: 8001
# Description: Optimized for code-completion tasks
#
# Model Name: davinci
# Completion Cost Per Token: 0.0200 / 1000
# Prompt Cost Per Token: 0.002 / 1000
# Maximum Tokens: 2049
# Description: Most capable GPT-3 model. Can do any task the other models can do, often with higher quality.
#
# Model Name: curie
# Completion Cost Per Token: 0.0020 / 1000
# Prompt Cost Per Token: None
# Maximum Tokens: 2049
# Description: Very capable, but faster and lower cost than Davinci.
#
# Model Name: babbage
# Completion Cost Per Token: 0.0005 / 1000
# Prompt Cost Per Token: None
# Maximum Tokens: 2049
# Description: Capable of straightforward tasks, very fast, and lower cost.
#
# Model Name: ada
# Completion Cost Per Token: 0.0004 / 1000
# Prompt Cost Per Token: None
# Maximum Tokens: 2049
# Description: Capable of very simple tasks, usually the fastest model in the GPT-3 series, and lowest cost.
#
# Model Name: code-davinci-001
# Completion Cost Per Token: 0.002 / 1000
# Prompt Cost Per Token: 0.002 / 1000
# Maximum Tokens: 8001
# Description: Earlier version of code-davinci-002
#
# Model Name: code-cushman-002
# Completion Cost Per Token: None
# Prompt Cost Per Token: None
# Maximum Tokens: 2048
# Description: Almost as capable as Davinci Codex, but slightly faster. This speed advantage may make it preferable for real-time applications.
#
# Model Name: code-cushman-001
# Completion Cost Per Token: None
# Prompt Cost Per Token: None
# Maximum Tokens: 2048
# Description: Earlier version of code-cushman-002

# %%
from llm_cost_estimation import estimate_cost

prompt = "Hello, how are you?"
model = "gpt-4"

# Estimate the cost for the completion
estimated_cost = estimate_cost(prompt, model)

print(f"Estimated cost of this completion: {estimated_cost}")
# Out:
# Estimated cost of this completion: 0.0005399999999999999
