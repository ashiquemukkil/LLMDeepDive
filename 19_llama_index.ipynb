# %% [markdown]
# # Llamaindex RAG

# %%
import os
os.environ["OPENAI_API_KEY"] = "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"

# %% [markdown]
# ### Creating Llamaindex Documents

# %%
from llama_index.core import SimpleDirectoryReader

pdf_path = "/Users/ashique/Downloads/machine_learning_linear_reg.pdf"
pdf_document = SimpleDirectoryReader(input_files=[pdf_path,]).load_data()

# %%
pdf_document
# Out:
# [Document(id_='c601aca2-73d3-4092-af43-2a765859d3b1', embedding=None, metadata={'page_label': '1', 'file_name': 'machine_learning_linear_reg.pdf', 'file_path': '/Users/ashique/Downloads/machine_learning_linear_reg.pdf', 'file_type': 'application/pdf', 'file_size': 43900, 'creation_date': '2024-03-16', 'last_modified_date': '2024-03-16'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='                  Linear Regression  Introduc)on  Linear regression is a fundamental supervised learning algorithm used in the ﬁeld of sta5s5cs and machine learning. It is employed to establish the rela5onship between a dependent variable and one or more independent variables. The objec5ve of linear regression is to ﬁnd the best-ﬁ?ng straight line that can depict the rela
# ...

# %% [markdown]
# ### Creating LlamaIndex Nodes

# %%
import tiktoken
from llama_index.core.node_parser import SimpleNodeParser

parser = SimpleNodeParser.from_defaults(separator=" ", chunk_size=1024, chunk_overlap=20,
  paragraph_separator="\n\n\n", secondary_chunking_regex="[^,.;。]+[,.;。]?",
  tokenizer=tiktoken.encoding_for_model("gpt-3.5-turbo").encode)


# Parse documents into nodes
nodes = parser.get_nodes_from_documents(pdf_document)
nodes
# Out:
# [TextNode(id_='f0621e85-80f3-4541-999c-f3795440d60a', embedding=None, metadata={'page_label': '1', 'file_name': 'machine_learning_linear_reg.pdf', 'file_path': '/Users/ashique/Downloads/machine_learning_linear_reg.pdf', 'file_type': 'application/pdf', 'file_size': 43900, 'creation_date': '2024-03-16', 'last_modified_date': '2024-03-16'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='c601aca2-73d3-4092-af43-2a765859d3b1', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'page_label': '1', 'file_name': 'machine_learning_linear_reg.pdf', 'file_path': '/Users/ashique/Downloads/machine_learning_linear_reg.pdf', 'file_type': 'application/pdf', 'file_size': 43900, 'creation_date': '2024-03-16', 'last_modified_d
# ...

# %% [markdown]
# ### Vector index

# %%
from llama_index.core import VectorStoreIndex

# Assuming docs is your list of Document objects
index = VectorStoreIndex(nodes)

# %% [markdown]
# ### set persist directory

# %%
path = "storage"
index.storage_context.persist(persist_dir=path)

# %% [markdown]
# ### Loading from disk

# %%
from llama_index.core import StorageContext, load_index_from_storage
storage_context = StorageContext.from_defaults(persist_dir=path)
index = load_index_from_storage(storage_context)

# %% [markdown]
# ### get Response

# %%
query = "your_query"
query_engine = index.as_query_engine()
response = query_engine.query(query)
print(response)
# Out:
# Linear regression is a widely used supervised learning algorithm that establishes the relationship between a dependent variable and one or more independent variables. It works by minimizing the vertical distances between observed data points and predicted values through the method of least squares. The model assumes a linear relationship between variables and can be computationally efficient when this assumption holds true. However, it may struggle with capturing complex non-linear patterns in the data and is sensitive to outliers and multicollinearity among independent variables.

# %%
response.source_nodes
# Out:
# [NodeWithScore(node=TextNode(id_='280e7b5b-bc5c-495a-ba10-23742b5ac43c', embedding=None, metadata={'page_label': '2', 'file_name': 'machine_learning_linear_reg.pdf', 'file_path': '/Users/ashique/Downloads/machine_learning_linear_reg.pdf', 'file_type': 'application/pdf', 'file_size': 43900, 'creation_date': '2024-03-16', 'last_modified_date': '2024-03-16'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='285f0048-1c62-42c1-a727-4d90dbaf5b7e', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'page_label': '2', 'file_name': 'machine_learning_linear_reg.pdf', 'file_path': '/Users/ashique/Downloads/machine_learning_linear_reg.pdf', 'file_type': 'application/pdf', 'file_size': 43900, 'creation_date': '2024-03-16
# ...
